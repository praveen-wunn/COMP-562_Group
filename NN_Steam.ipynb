# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import datetime
import math
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras import layers
from math import floor, ceil
from pylab import rcParams
# %matplotlib inline
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
p = lambda x: f'/content/drive/My Drive/MLfinal/{x}'
iter_csv = pd.read_csv('/content/drive/My Drive/MLfinal/updated_train.csv', iterator=True, chunksize=100000)
train = pd.concat([chunk[chunk['2'] == 1] for chunk in iter_csv])
iter_csv = pd.read_csv('/content/drive/My Drive/MLfinal/updated_test.csv', iterator=True, chunksize=100000)
test = pd.concat([chunk[chunk['2'] == 1] for chunk in iter_csv])
#train = pd.read_csv(p('updated_train.csv')).loc[train['0'] == 1,]
#test = pd.read_csv(p('updated_test.csv')).loc[test['0'] == 1,]

# %%
train.dropna(inplace=True)
test.dropna(inplace=True)

# %%
train_labels = train.meter_reading
train_dataset = train.drop(columns=['meter_reading','1','2','3','0'])
test_labels = test.meter_reading
test_data = test.drop(columns = ['meter_reading','1','2','3','0'])

# %%
print(train_dataset.shape)
print(train_labels.shape)
print(test_data.shape)
print(test_labels.shape)
print(test.shape)
print(train.shape)
# Out:
# (1800072, 35)
# (1800072,)
# (899991, 35)
# (899991,)
# (899991, 40)
# (1800072, 40)

# %%
# Define a simple sequential model
def create_model():
  model = tf.keras.models.Sequential([
    keras.layers.Dense(100, input_dim=35, activation= "relu"),
    keras.layers.Dense(1)
  ])

  model.compile(optimizer='adam',
                loss='mean_squared_error',
                metrics=['accuracy'])

  return model

# Create a basic model instance
model = create_model()

# Display the model's architecture
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               3600
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 3,701
# Trainable params: 3,701
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss= "mean_squared_error" , optimizer="adam", metrics=['mean_squared_error','accuracy'])
#mean_squared_logarithmic_error;accuracy

# %%
# Fit Model
import time
import os
starttime = time.time()

checkpoint_path = "/content/drive/My Drive/training_1/cp2.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

# Train the model with the new callback
model.fit(train_dataset, 
          train_labels,  
          epochs=10,
          callbacks=[cp_callback])  # Pass callback to training

print(time.time() - starttime)
# This may generate warnings related to saving the state of the optimizer.
# These warnings (and similar warnings throughout this notebook)
# are in place to discourage outdated usage, and can be ignored.
# Out:
# Train on 1800072 samples
# Epoch 1/10
# 1799616/1800072 [============================>.] - ETA: 0s - loss: 175327046009.4790 - mean_squared_error: 175312338944.0000 - acc: 8.6685e-05
# Epoch 00001: saving model to /content/drive/My Drive/training_1/cp2.ckpt
# 1800072/1800072 [==============================] - 84s 47us/sample - loss: 175282752930.0435 - mean_squared_error: 175268003840.0000 - acc: 8.6663e-05
# Epoch 2/10
# 1799392/1800072 [============================>.] - ETA: 0s - loss: 175161696491.0665 - mean_squared_error: 175149645824.0000 - acc: 4.9461e-05
# Epoch 00002: saving model to /content/drive/My Drive/training_1/cp2.ckpt
# 1800072/1800072 [==============================] - 85s 47us/sample - loss: 175250215296.8725 - mean_squared_error: 175238103040.0000 - acc: 4.9442e-05
# Epoch 3/10
# 1799840/1800072 [============================>.] - ETA: 0s - loss: 175273433058.7364 - mean_squared_error: 175263236096.0000 - acc: 6.3783e-04
# Epoch 00003: saving model to /content/drive/My Drive/training_1/cp2.ckpt
# 1800072/1800072 [==============================] - 84s 47us/sample - loss: 175250868105.8926 - mean_squared_error: 175240658944.0000 - acc: 6.3775e-04
# Epoch 4/10
# 1799456/1800072 [============================>.] - ETA: 0s - loss: 175306177982.9552 - mean_squared_error: 175287730176.0000 - acc: 0.0015
# Epoch 00004: saving model to /content/drive/My Drive/training_1/cp2.ckpt
# 1800072/1800072 [==============================] - 85s 47us/sample - loss: 175246316020.2643 - mean_squared_error: 175227813888.0000 - acc: 0.0015
# Epoch 5/10
# 1799808/1800072 [============================>.] - ETA: 0s - loss: 175272286192.7603 - mean_squared_error: 175259041792.0000 - acc: 0.0024
# Epoch 00005: saving model to /content/drive/My Drive/training_1/cp2.ckpt
# 1800072/1800072 [==============================] - 86s 48us/sample - loss: 175246672682.5362 - mean_squared_error: 175233433600.0000 - acc: 0.0024
# Epoch 6/10
# 1799200/1800072 [============================>.] - ETA: 0s - loss: 175319793989.1561 - mean_squared_error: 175308439552.0000 - acc: 0.0032
# Epoch 00006: saving model to /content/drive/My Drive/training_1/cp2.ckpt
# 1800072/1800072 [==============================] - 87s 48us/sample - loss: 175235057767.4563 - mean_squared_error: 175223668736.0000 - acc: 0.0032
# Epoch 7/10
# 1799136/1800072 [============================>.] - ETA: 0s - loss: 175102167187.4342 - mean_squared_error: 175092744192.0000 - acc: 0.0025
# Epoch 00007: saving model to /content/drive/My Drive/training_1/cp2.ckpt
# 1800072/1800072 [==============================] - 85s 47us/sample - loss: 175218550282.1248 - mean_squared_error: 175209136128.0000 - acc: 0.0025
# Epoch 8/10
# 1799552/1800072 [============================>.] - ETA: 0s - loss: 175123086076.7073 - mean_squared_error: 175108685824.0000 - acc: 0.0043
# Epoch 00008: saving model to /content/drive/My Drive/training_1/cp2.ckpt
# 1800072/1800072 [==============================] - 85s 47us/sample - loss: 175215008637.4892 - mean_squared_error: 175200583680.0000 - acc: 0.0043
# Epoch 9/10
# 1799296/1800072 [============================>.] - ETA: 0s - loss: 174718435215.7299 - mean_squared_error: 174705459200.0000 - acc: 0.0063
# Epoch 00009: saving model to /content/drive/My Drive/training_1/cp2.ckpt
# 1800072/1800072 [==============================] - 85s 47us/sample - loss: 175209705372.5622 - mean_squared_error: 175196733440.0000 - acc: 0.0063
# Epoch 10/10
# 1799680/1800072 [============================>.] - ETA: 0s - loss: 175196403748.8863 - mean_squared_error: 175182200832.0000 - acc: 0.0084
# Epoch 00010: saving model to /content/drive/My Drive/training_1/cp2.ckpt
# 1800072/1800072 [==============================] - 86s 48us/sample - loss: 175206829650.4055 - mean_squared_error: 175192571904.0000 - acc: 0.0084
# 853.9228146076202

# %%
#Evaluation for Neural Network Model
pred= model.predict(test_data)
score = np.sqrt(mean_squared_error(test_labels,pred))
print (score)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-b3ed6897dd2f> in <module>()
#       1 pred= model.predict(test_data)
# ----> 2 score = np.sqrt(mean_squared_error(test_labels,pred))
#       3 print (score)
#
# NameError: name 'mean_squared_error' is not defined

# %%
loss, mae, mse = model.evaluate(test_data, test_labels, verbose=2)

print("Testing set Mean Abs Error: {:5.2f} MPG".format(mae))
# Out:
# 899991/899991 - 17s - loss: 175037709934.4415 - mean_squared_error: 175020179456.0000 - acc: 0.0086
# Testing set Mean Abs Error: 175020179456.00 MPG

# %%
test_predictions = model.predict(test_data).flatten()

# %%
a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [kWh]')
plt.ylabel('Predictions [kWh]')
lims = [-1000, 5000]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)
