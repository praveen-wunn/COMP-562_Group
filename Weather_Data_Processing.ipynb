# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import datetime
import math

# %%
p = lambda x: f'/content/drive/My Drive/MLfinal/{x}'
train_df = pd.read_csv(p('test.csv'))
weather_df = pd.read_csv(p('weather_test.csv'))
building_metadata_df = pd.read_csv(p('building_metadata.csv'))

# %%
def print_density(data, name="Data"):
  print(f"{name} Density:")
  for column in data.columns:
    density = str(100 * (len(data) - np.sum(data[column].isnull())) / len (data))
    print(column + ': ' + density)
  print('\n')

print_density(train_df, "Test Data")
print_density(weather_df, "Weather Data")
print_density(building_metadata_df, "Building Metadata")
# Out:
# Test Data Density:
# row_id: 100.0
# building_id: 100.0
# meter: 100.0
# timestamp: 100.0
#
#
# Weather Data Density:
# site_id: 100.0
# timestamp: 100.0
# air_temperature: 99.9624877814769
# cloud_coverage: 49.341191662188045
# dew_temperature: 99.88205292829755
# precip_depth_1_hr: 65.52194284436396
# sea_level_pressure: 92.32983339525254
# wind_direction: 95.53821016220428
# wind_speed: 99.83408057191706
#
#
# Building Metadata Density:
# site_id: 100.0
# building_id: 100.0
# primary_use: 100.0
# square_feet: 100.0
# year_built: 46.58385093167702
# floor_count: 24.499654934437544

# %%
train_df["timestamp"] = [datetime.datetime.strptime(time_stamp, '%Y-%m-%d %H:%M:%S') for time_stamp in train_df["timestamp"]]

# %%
weather_df["timestamp"] = [datetime.datetime.strptime(time_stamp, '%Y-%m-%d %H:%M:%S') for time_stamp in weather_df["timestamp"]]

# %%
# convert timestamp column to datetime object
weather_df["year"] = [time_stamp.year for time_stamp in weather_df["timestamp"]]
weather_df["month"] = [time_stamp.month for time_stamp in weather_df["timestamp"]]
weather_df["day"] = [time_stamp.day for time_stamp in weather_df["timestamp"]]
weather_df["hour"] = [time_stamp.hour for time_stamp in weather_df["timestamp"]]

# %% [markdown]
# fill in missing weather data

# %%
new_weather_df = weather_df.copy()

# %% [markdown]
# delete precip_depth_1_hr, cloud_coverage, and 'sea_level_pressure' because missing for entire sites

# %%
new_weather_df.drop(columns=['sea_level_pressure', 'cloud_coverage', 'precip_depth_1_hr'], inplace=True)

# %%
null_weather_cols = ['air_temperature', 'dew_temperature', 'wind_direction', 'wind_speed']

# %%
count = 0
for site in new_weather_df.site_id.unique():
  site_data = new_weather_df.loc[weather_df.site_id == site, ]
  site_null_rows = site_data[site_data.isnull().any(axis=1)]
  for column in null_weather_cols:
    null_indices = site_null_rows[site_null_rows[column].isnull()].index
    for index, row in site_null_rows.iterrows():
      if index in null_indices:
        max_index = site_data.index.max()
        min_index = site_data.index.min()
        prev_day = new_weather_df.loc[index-1, column] if index !=min_index else float('NaN')
        next_day = new_weather_df.loc[index+1, column] if index != max_index else float('NaN')
      # new_value = prev_day if if math.isnan(next_day) else np.mean([prev_day, next_day])
        # weather_df.loc[index, column] = prev_day if math.isnan(next_day) else np.mean([prev_day, next_day])
        if math.isnan(prev_day):
          if math.isnan(next_day): # take avg of that month, and hour, and site
            count+= 1
            new_val = np.mean(site_data.loc[(site_data.month == row.month) & (site_data.hour == row.hour), column])
          # print(row)
          else: # future not prev
            new_val = next_day
        elif math.isnan(next_day): # no future
          new_val = prev_day
        else: # both
          new_val = np.mean([prev_day, next_day])
        new_weather_df.loc[index, column] = new_val
    print('done ', site, column)
# Out:
# done  0 air_temperature
# done  0 dew_temperature
# done  0 wind_direction
# done  0 wind_speed
# done  1 air_temperature
# done  1 dew_temperature
# done  1 wind_direction
# done  1 wind_speed
# done  2 air_temperature
# done  2 dew_temperature
# done  2 wind_direction
# done  2 wind_speed
# done  3 air_temperature
# done  3 dew_temperature
# done  3 wind_direction
# done  3 wind_speed
# done  4 air_temperature
# done  4 dew_temperature
# done  4 wind_direction
# done  4 wind_speed
# done  5 air_temperature
# done  5 dew_temperature
# done  5 wind_direction
# done  5 wind_speed
# done  6 air_temperature
# done  6 dew_temperature
# done  6 wind_direction
# done  6 wind_speed
# done  7 air_temperature
# done  7 dew_temperature
# done  7 wind_direction
# done  7 wind_speed
# done  8 air_temperature
# done  8 dew_temperature
# done  8 wind_direction
# done  8 wind_speed
# done  9 air_temperature
# done  9 dew_temperature
# done  9 wind_direction
# done  9 wind_speed
# done  10 air_temperature
# done  10 dew_temperature
# done  10 wind_direction
# done  10 wind_speed
# done  11 air_temperature
# done  11 dew_temperature
# done  11 wind_direction
# done  11 wind_speed
# done  12 air_temperature
# done  12 dew_temperature
# done  12 wind_direction
# done  12 wind_speed
# done  13 air_temperature
# done  13 dew_temperature
# done  13 wind_direction
# done  13 wind_speed
# done  14 air_temperature
# done  14 dew_temperature
# done  14 wind_direction
# done  14 wind_speed
# done  15 air_temperature
# done  15 dew_temperature
# done  15 wind_direction
# done  15 wind_speed

# %% [markdown]
# Merge the dataset

# %%
building_meter_data = train_df.merge(building_metadata_df, how = 'left', on='building_id')

# %%
merged_data = building_meter_data.merge(new_weather_df, how = 'left', on=['timestamp', 'site_id'])

# %%
null_weather_times = merged_data.loc[merged_data.air_temperature.isnull(), ['timestamp', 'site_id']]
null_weather_times.drop_duplicates(subset=None, keep='first', inplace=True)

# %%
null_weather_times
# Out:
#                    timestamp  site_id
# 41498571 2017-01-18 09:00:00        1
# 41498634 2017-01-18 19:00:00        1
# 41498697 2017-08-08 03:00:00        1
# 41498760 2017-08-15 18:00:00        1
# 41498823 2017-08-15 19:00:00        1
# ...                      ...      ...
# 41696822 2017-12-25 04:00:00       11
# 41696836 2017-12-25 07:00:00       11
# 41696850 2018-05-09 05:00:00       15
# 41697100 2018-05-09 06:00:00       15
# 41697350 2018-05-09 07:00:00       15
#
# [3077 rows x 2 columns]

# %%
final_weather = new_weather_df.copy()

# %%
new_null_weather_times = []
count = 0
for index, timeset in null_weather_times.iterrows():
  time_val = timeset.timestamp
  site = timeset.site_id
  prev_hour = new_weather_df.loc[(new_weather_df.timestamp == (null_weather_times.loc[index, 'timestamp'] - np.timedelta64(1, 'h'))) & (new_weather_df.site_id ==site) ,] if time_val.hour != 0 else float('NaN')
  next_hour = new_weather_df.loc[(new_weather_df.timestamp == (null_weather_times.loc[index, 'timestamp'] + np.timedelta64(1, 'h'))) & (new_weather_df.site_id ==site) ,] if time_val.hour != 11 else float('NaN')
  if not isinstance(prev_hour, float):  
    prev_hour = float('NaN') if prev_hour.empty else prev_hour
  if not isinstance(next_hour, float):
    next_hour = float('NaN') if next_hour.empty else next_hour
  if isinstance(prev_hour, float): # no prev row
    if isinstance(next_hour, float):
     # print(index, "NO SURROUNDING TIME STAMP")
     # new_count+= 1
      new_null_weather_times.append([time_val, site])
    else:
      new_row = next_hour.copy()
     # print(index, "prev_only")
      new_row.timestamp.iloc[0] = time_val
      new_row.month.iloc[0] = time_val.month
      new_row.day.iloc[0] = time_val.day
      new_row.hour.iloc[0] = time_val.hour
      count+= 1
     # print(new_row, " prev_only")
  elif isinstance(next_hour, float): # prev row, no future row
    new_row = prev_hour.copy()
   # print(index, "future only")
    new_row.timestamp.iloc[0] = time_val
    new_row.month.iloc[0] = time_val.month
    new_row.day.iloc[0] = time_val.day
    new_row.hour.iloc[0] = time_val.hour
    count+= 1
  #  print(new_row, " future_only")
  else: # average both rows
    # join two rows
  #  print(index, "both")
    both_rows = prev_hour.append(next_hour)
    test_means = np.mean(both_rows.loc[:,['air_temperature', 'dew_temperature', 'wind_direction', 'wind_speed']]).values
    new_row = [site, time_val]
    for value in test_means:
      new_row.append(value)
    new_row.append(time_val.year)
    new_row.append(time_val.month)
    new_row.append(time_val.day)
    new_row.append(time_val.hour)
    new_row = pd.DataFrame([new_row], columns=new_weather_df.columns)
   # print(new_row, " both") 
    count+= 1
  final_weather = final_weather.append(new_row)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %% [markdown]
# Sort Data Frame then try again

# %%
final_weather = final_weather.sort_values(by=['site_id', 'timestamp'])

# %%
final_weather.drop_duplicates(subset=None, keep='first', inplace=True)

# %%
final_weather.shape[0]-new_weather_df.shape[0]
# Out:
# 833

# %%
count
# Out:
# 833

# %%
new_null_weather_times = pd.DataFrame(new_null_weather_times, columns=null_weather_times.columns)

# %%
new_null_weather_times
# Out:
#                timestamp  site_id
# 0    2017-08-15 19:00:00        1
# 1    2018-07-08 16:00:00        1
# 2    2018-07-08 17:00:00        1
# 3    2018-08-08 20:00:00        1
# 4    2018-09-15 18:00:00        1
# ...                  ...      ...
# 2239 2017-12-18 18:00:00       11
# 2240 2017-12-18 19:00:00       11
# 2241 2017-12-18 20:00:00       11
# 2242 2017-12-18 21:00:00       11
# 2243 2018-05-09 06:00:00       15
#
# [2244 rows x 2 columns]

# %%
appended_weather = final_weather.copy()

# %%
third_null_weather_times = []
new_count = 0
count = 0
for index, timeset in new_null_weather_times.iterrows():
  time_val = timeset.timestamp
  site = timeset.site_id
  prev_hour = final_weather.loc[(final_weather.timestamp == (new_null_weather_times.loc[index, 'timestamp'] - np.timedelta64(1, 'h'))) & (final_weather.site_id ==site) ,] if time_val.hour != 0 else float('NaN')
  next_hour = final_weather.loc[(final_weather.timestamp == (new_null_weather_times.loc[index, 'timestamp'] + np.timedelta64(1, 'h'))) & (final_weather.site_id ==site) ,] if time_val.hour != 11 else float('NaN')
  if not isinstance(prev_hour, float):  
    prev_hour = float('NaN') if prev_hour.empty else prev_hour
  if not isinstance(next_hour, float):
    next_hour = float('NaN') if next_hour.empty else next_hour
  if isinstance(prev_hour, float): # no prev row
    if isinstance(next_hour, float):
      # print(index, "NO SURROUNDING TIME STAMP")
      # take the average of mnth and day for that site
      site_data = final_weather.loc[(final_weather.site_id == site) & (final_weather.month == time_val.month) & (final_weather.day == time_val.day),]
      new_count+= 1
      count+= 1
      third_null_weather_times.append([time_val, site])
      test_means = np.mean(site_data.loc[:,['air_temperature', 'dew_temperature', 'wind_direction', 'wind_speed']]).values
      new_row_array = [site, time_val]
      for value in test_means:
        new_row_array.append(value)
      new_row_array.append(time_val.year)
      new_row_array.append(time_val.month)
      new_row_array.append(time_val.day)
      new_row_array.append(time_val.hour)
      new_row = pd.DataFrame([new_row_array], columns=appended_weather.columns)
      print(new_row)
    else:
      new_row = next_hour
     # print(index, "prev_only")
      new_row.iloc[0].timestamp = time_val
      new_row.iloc[0].month = time_val.month
      new_row.iloc[0].day = time_val.day
      new_row.iloc[0].hour = time_val.hour
      count+= 1
     # print(new_row, " prev_only")
  elif isinstance(next_hour, float): # prev row, no future row
    new_row = prev_hour
   # print(index, "future only")
    new_row.iloc[0].timestamp = time_val
    new_row.iloc[0].month = time_val.month
    new_row.iloc[0].day = time_val.day
    new_row.iloc[0].hour = time_val.hour
    count+= 1
  #  print(new_row, " future_only")
  else: # average both rows
    # join two rows
  #  print(index, "both")
    both_rows = prev_hour.append(next_hour)
    test_means = np.mean(both_rows.loc[:,['air_temperature', 'dew_temperature', 'wind_direction', 'wind_speed']]).values
    new_row_array = [site, time_val]
    for value in test_means:
      new_row_array.append(value)
    new_row_array.append(time_val.year)
    new_row_array.append(time_val.month)
    new_row_array.append(time_val.day)
    new_row_array.append(time_val.hour)
    new_row = pd.DataFrame([new_row_array], columns=appended_weather.columns)
   # print(new_row, " both") 
    count+= 1
  appended_weather = appended_weather.append(new_row)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-15 19:00:00        13.351111  ...      9   15    19
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-17 05:00:00        14.251613  ...      9   17     5
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-17 06:00:00        14.251613  ...      9   17     6
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-17 07:00:00        14.251613  ...      9   17     7
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-17 08:00:00        14.251613  ...      9   17     8
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-17 09:00:00        14.251613  ...      9   17     9
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-17 10:00:00        14.251613  ...      9   17    10
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-17 11:00:00        14.251613  ...      9   17    11
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-17 16:00:00        14.251613  ...      9   17    16
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-17 17:00:00        14.251613  ...      9   17    17
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-17 18:00:00        14.251613  ...      9   17    18
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-17 19:00:00        14.251613  ...      9   17    19
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-17 20:00:00        14.251613  ...      9   17    20
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-17 21:00:00        14.251613  ...      9   17    21
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-17 22:00:00        14.251613  ...      9   17    22
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-17 23:00:00        14.251613  ...      9   17    23
#
# [1 rows x 10 columns]
#    site_id  timestamp  air_temperature  dew_temperature  ...  year  month  day  hour
# 0        1 2018-09-18        15.769231        10.988462  ...  2018      9   18     0
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-18 01:00:00        15.769231  ...      9   18     1
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-18 02:00:00        15.769231  ...      9   18     2
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-18 03:00:00        15.769231  ...      9   18     3
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-18 04:00:00        15.769231  ...      9   18     4
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-18 05:00:00        15.769231  ...      9   18     5
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-18 06:00:00        15.769231  ...      9   18     6
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-18 07:00:00        15.769231  ...      9   18     7
#
# [1 rows x 10 columns]
#    site_id  timestamp  air_temperature  dew_temperature  ...  year  month  day  hour
# 0        1 2018-09-24        15.209677         9.151613  ...  2018      9   24     0
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-24 01:00:00        15.209677  ...      9   24     1
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-24 02:00:00        15.209677  ...      9   24     2
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-24 03:00:00        15.209677  ...      9   24     3
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-24 04:00:00        15.209677  ...      9   24     4
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-24 05:00:00        15.209677  ...      9   24     5
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-24 06:00:00        15.209677  ...      9   24     6
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-24 07:00:00        15.209677  ...      9   24     7
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-24 08:00:00        15.209677  ...      9   24     8
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-24 09:00:00        15.209677  ...      9   24     9
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-24 10:00:00        15.209677  ...      9   24    10
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-24 11:00:00        15.209677  ...      9   24    11
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-24 12:00:00        15.209677  ...      9   24    12
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-24 13:00:00        15.209677  ...      9   24    13
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-24 14:00:00        15.209677  ...      9   24    14
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-09-24 15:00:00        15.209677  ...      9   24    15
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-16 19:00:00        10.640476  ...     11   16    19
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-16 20:00:00        10.640476  ...     11   16    20
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-16 21:00:00        10.640476  ...     11   16    21
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-16 22:00:00        10.640476  ...     11   16    22
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-16 23:00:00        10.640476  ...     11   16    23
#
# [1 rows x 10 columns]
#    site_id  timestamp  air_temperature  dew_temperature  ...  year  month  day  hour
# 0        1 2018-11-17         5.154167         1.304167  ...  2018     11   17     0
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-17 01:00:00         5.154167  ...     11   17     1
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-17 02:00:00         5.154167  ...     11   17     2
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-17 03:00:00         5.154167  ...     11   17     3
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-17 04:00:00         5.154167  ...     11   17     4
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-17 05:00:00         5.154167  ...     11   17     5
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-17 06:00:00         5.154167  ...     11   17     6
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-17 07:00:00         5.154167  ...     11   17     7
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-17 08:00:00         5.154167  ...     11   17     8
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-17 09:00:00         5.154167  ...     11   17     9
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-17 10:00:00         5.154167  ...     11   17    10
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-17 11:00:00         5.154167  ...     11   17    11
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-17 12:00:00         5.154167  ...     11   17    12
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-17 13:00:00         5.154167  ...     11   17    13
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-17 14:00:00         5.154167  ...     11   17    14
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-17 15:00:00         5.154167  ...     11   17    15
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-17 16:00:00         5.154167  ...     11   17    16
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-17 17:00:00         5.154167  ...     11   17    17
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-17 18:00:00         5.154167  ...     11   17    18
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-17 19:00:00         5.154167  ...     11   17    19
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-17 20:00:00         5.154167  ...     11   17    20
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-17 21:00:00         5.154167  ...     11   17    21
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-17 22:00:00         5.154167  ...     11   17    22
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-17 23:00:00         5.154167  ...     11   17    23
#
# [1 rows x 10 columns]
#    site_id  timestamp  air_temperature  dew_temperature  ...  year  month  day  hour
# 0        1 2018-11-18         6.945833            4.875  ...  2018     11   18     0
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-18 01:00:00         6.945833  ...     11   18     1
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-18 02:00:00         6.945833  ...     11   18     2
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-18 03:00:00         6.945833  ...     11   18     3
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-18 04:00:00         6.945833  ...     11   18     4
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-18 05:00:00         6.945833  ...     11   18     5
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-18 06:00:00         6.945833  ...     11   18     6
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-18 07:00:00         6.945833  ...     11   18     7
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-18 08:00:00         6.945833  ...     11   18     8
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-18 09:00:00         6.945833  ...     11   18     9
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-18 10:00:00         6.945833  ...     11   18    10
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-18 11:00:00         6.945833  ...     11   18    11
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-18 12:00:00         6.945833  ...     11   18    12
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-18 13:00:00         6.945833  ...     11   18    13
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-18 14:00:00         6.945833  ...     11   18    14
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-18 15:00:00         6.945833  ...     11   18    15
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-18 16:00:00         6.945833  ...     11   18    16
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-18 17:00:00         6.945833  ...     11   18    17
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-18 18:00:00         6.945833  ...     11   18    18
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-18 19:00:00         6.945833  ...     11   18    19
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-18 20:00:00         6.945833  ...     11   18    20
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-18 21:00:00         6.945833  ...     11   18    21
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-18 22:00:00         6.945833  ...     11   18    22
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-18 23:00:00         6.945833  ...     11   18    23
#
# [1 rows x 10 columns]
#    site_id  timestamp  air_temperature  dew_temperature  ...  year  month  day  hour
# 0        1 2018-11-19         5.495833         2.579167  ...  2018     11   19     0
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-19 01:00:00         5.495833  ...     11   19     1
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-19 02:00:00         5.495833  ...     11   19     2
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-19 03:00:00         5.495833  ...     11   19     3
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-19 04:00:00         5.495833  ...     11   19     4
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-19 05:00:00         5.495833  ...     11   19     5
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-19 06:00:00         5.495833  ...     11   19     6
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-19 07:00:00         5.495833  ...     11   19     7
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-19 08:00:00         5.495833  ...     11   19     8
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-19 09:00:00         5.495833  ...     11   19     9
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-19 10:00:00         5.495833  ...     11   19    10
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-19 11:00:00         5.495833  ...     11   19    11
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-19 12:00:00         5.495833  ...     11   19    12
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-19 13:00:00         5.495833  ...     11   19    13
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-19 14:00:00         5.495833  ...     11   19    14
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-19 15:00:00         5.495833  ...     11   19    15
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-19 16:00:00         5.495833  ...     11   19    16
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-19 17:00:00         5.495833  ...     11   19    17
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-19 18:00:00         5.495833  ...     11   19    18
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-19 19:00:00         5.495833  ...     11   19    19
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-19 20:00:00         5.495833  ...     11   19    20
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-19 21:00:00         5.495833  ...     11   19    21
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-19 22:00:00         5.495833  ...     11   19    22
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-19 23:00:00         5.495833  ...     11   19    23
#
# [1 rows x 10 columns]
#    site_id  timestamp  air_temperature  dew_temperature  ...  year  month  day  hour
# 0        1 2018-11-20        10.279167              8.7  ...  2018     11   20     0
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-20 01:00:00        10.279167  ...     11   20     1
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-20 02:00:00        10.279167  ...     11   20     2
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-20 03:00:00        10.279167  ...     11   20     3
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-20 04:00:00        10.279167  ...     11   20     4
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-20 05:00:00        10.279167  ...     11   20     5
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-20 06:00:00        10.279167  ...     11   20     6
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-20 07:00:00        10.279167  ...     11   20     7
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-20 08:00:00        10.279167  ...     11   20     8
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-20 09:00:00        10.279167  ...     11   20     9
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-20 10:00:00        10.279167  ...     11   20    10
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-20 11:00:00        10.279167  ...     11   20    11
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-20 12:00:00        10.279167  ...     11   20    12
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-20 13:00:00        10.279167  ...     11   20    13
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-20 14:00:00        10.279167  ...     11   20    14
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-20 15:00:00        10.279167  ...     11   20    15
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-20 16:00:00        10.279167  ...     11   20    16
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-20 17:00:00        10.279167  ...     11   20    17
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-20 18:00:00        10.279167  ...     11   20    18
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-20 19:00:00        10.279167  ...     11   20    19
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-20 20:00:00        10.279167  ...     11   20    20
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-20 21:00:00        10.279167  ...     11   20    21
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-20 22:00:00        10.279167  ...     11   20    22
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-20 23:00:00        10.279167  ...     11   20    23
#
# [1 rows x 10 columns]
#    site_id  timestamp  air_temperature  dew_temperature  ...  year  month  day  hour
# 0        1 2018-11-21        12.858333        10.116667  ...  2018     11   21     0
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-21 01:00:00        12.858333  ...     11   21     1
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-21 02:00:00        12.858333  ...     11   21     2
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-21 03:00:00        12.858333  ...     11   21     3
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-21 04:00:00        12.858333  ...     11   21     4
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-21 05:00:00        12.858333  ...     11   21     5
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-21 06:00:00        12.858333  ...     11   21     6
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-21 07:00:00        12.858333  ...     11   21     7
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-21 08:00:00        12.858333  ...     11   21     8
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-21 09:00:00        12.858333  ...     11   21     9
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-21 10:00:00        12.858333  ...     11   21    10
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-21 11:00:00        12.858333  ...     11   21    11
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-21 12:00:00        12.858333  ...     11   21    12
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-21 13:00:00        12.858333  ...     11   21    13
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-21 14:00:00        12.858333  ...     11   21    14
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-21 15:00:00        12.858333  ...     11   21    15
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-21 16:00:00        12.858333  ...     11   21    16
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-21 17:00:00        12.858333  ...     11   21    17
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-21 18:00:00        12.858333  ...     11   21    18
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-21 19:00:00        12.858333  ...     11   21    19
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-21 20:00:00        12.858333  ...     11   21    20
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-21 21:00:00        12.858333  ...     11   21    21
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-21 22:00:00        12.858333  ...     11   21    22
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-21 23:00:00        12.858333  ...     11   21    23
#
# [1 rows x 10 columns]
#    site_id  timestamp  air_temperature  dew_temperature  ...  year  month  day  hour
# 0        1 2018-11-22        13.196296         8.703704  ...  2018     11   22     0
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-22 01:00:00        13.196296  ...     11   22     1
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-22 02:00:00        13.196296  ...     11   22     2
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-22 03:00:00        13.196296  ...     11   22     3
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-22 04:00:00        13.196296  ...     11   22     4
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-22 05:00:00        13.196296  ...     11   22     5
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-22 06:00:00        13.196296  ...     11   22     6
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-22 07:00:00        13.196296  ...     11   22     7
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-22 08:00:00        13.196296  ...     11   22     8
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-22 09:00:00        13.196296  ...     11   22     9
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-22 10:00:00        13.196296  ...     11   22    10
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-22 11:00:00        13.196296  ...     11   22    11
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-22 12:00:00        13.196296  ...     11   22    12
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-22 13:00:00        13.196296  ...     11   22    13
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-22 14:00:00        13.196296  ...     11   22    14
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-22 15:00:00        13.196296  ...     11   22    15
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-22 16:00:00        13.196296  ...     11   22    16
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-22 17:00:00        13.196296  ...     11   22    17
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-22 18:00:00        13.196296  ...     11   22    18
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2018-11-22 19:00:00        13.196296  ...     11   22    19
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-04-11 13:00:00         8.707317  ...      4   11    13
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-04-11 14:00:00         8.707317  ...      4   11    14
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-04-11 15:00:00         8.707317  ...      4   11    15
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-04-11 16:00:00         8.707317  ...      4   11    16
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-04-11 17:00:00         8.707317  ...      4   11    17
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-15 19:00:00        13.222222  ...      9   15    19
#
# [1 rows x 10 columns]
#    site_id  timestamp  air_temperature  dew_temperature  ...  year  month  day  hour
# 0        5 2018-09-16        13.244444        11.333333  ...  2018      9   16     0
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-17 05:00:00        12.107143  ...      9   17     5
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-17 06:00:00        12.107143  ...      9   17     6
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-17 07:00:00        12.107143  ...      9   17     7
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-17 08:00:00        12.107143  ...      9   17     8
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-17 09:00:00        12.107143  ...      9   17     9
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-17 10:00:00        12.107143  ...      9   17    10
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-17 11:00:00        12.107143  ...      9   17    11
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-17 12:00:00        12.107143  ...      9   17    12
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-17 13:00:00        12.107143  ...      9   17    13
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-17 14:00:00        12.107143  ...      9   17    14
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-17 15:00:00        12.107143  ...      9   17    15
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-17 16:00:00        12.107143  ...      9   17    16
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-17 17:00:00        12.107143  ...      9   17    17
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-17 18:00:00        12.107143  ...      9   17    18
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-17 19:00:00        12.107143  ...      9   17    19
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-17 20:00:00        12.107143  ...      9   17    20
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-17 21:00:00        12.107143  ...      9   17    21
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-17 22:00:00        12.107143  ...      9   17    22
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-17 23:00:00        12.107143  ...      9   17    23
#
# [1 rows x 10 columns]
#    site_id  timestamp  air_temperature  dew_temperature  ...  year  month  day  hour
# 0        5 2018-09-18        14.434211        11.407895  ...  2018      9   18     0
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-18 01:00:00        14.434211  ...      9   18     1
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-18 02:00:00        14.434211  ...      9   18     2
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-18 03:00:00        14.434211  ...      9   18     3
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-18 04:00:00        14.434211  ...      9   18     4
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-18 05:00:00        14.434211  ...      9   18     5
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-18 06:00:00        14.434211  ...      9   18     6
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-18 07:00:00        14.434211  ...      9   18     7
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-18 08:00:00        14.434211  ...      9   18     8
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-20 07:00:00        15.488889  ...      9   20     7
#
# [1 rows x 10 columns]
#    site_id  timestamp  air_temperature  dew_temperature  ...  year  month  day  hour
# 0        5 2018-09-24        14.172414        12.551724  ...  2018      9   24     0
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-24 01:00:00        14.172414  ...      9   24     1
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-24 02:00:00        14.172414  ...      9   24     2
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-24 03:00:00        14.172414  ...      9   24     3
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-24 04:00:00        14.172414  ...      9   24     4
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-24 05:00:00        14.172414  ...      9   24     5
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-24 06:00:00        14.172414  ...      9   24     6
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-24 07:00:00        14.172414  ...      9   24     7
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-24 08:00:00        14.172414  ...      9   24     8
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-24 09:00:00        14.172414  ...      9   24     9
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-24 10:00:00        14.172414  ...      9   24    10
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-24 11:00:00        14.172414  ...      9   24    11
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-24 12:00:00        14.172414  ...      9   24    12
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-24 13:00:00        14.172414  ...      9   24    13
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-24 14:00:00        14.172414  ...      9   24    14
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-24 15:00:00        14.172414  ...      9   24    15
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-24 16:00:00        14.172414  ...      9   24    16
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-09-24 17:00:00        14.172414  ...      9   24    17
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-16 19:00:00        10.738095  ...     11   16    19
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-16 20:00:00        10.738095  ...     11   16    20
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-16 21:00:00        10.738095  ...     11   16    21
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-16 22:00:00        10.738095  ...     11   16    22
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-16 23:00:00        10.738095  ...     11   16    23
#
# [1 rows x 10 columns]
#    site_id  timestamp  air_temperature  dew_temperature  ...  year  month  day  hour
# 0        5 2018-11-17         4.916667         1.458333  ...  2018     11   17     0
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-17 01:00:00         4.916667  ...     11   17     1
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-17 02:00:00         4.916667  ...     11   17     2
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-17 03:00:00         4.916667  ...     11   17     3
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-17 04:00:00         4.916667  ...     11   17     4
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-17 05:00:00         4.916667  ...     11   17     5
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-17 06:00:00         4.916667  ...     11   17     6
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-17 07:00:00         4.916667  ...     11   17     7
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-17 08:00:00         4.916667  ...     11   17     8
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-17 09:00:00         4.916667  ...     11   17     9
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-17 10:00:00         4.916667  ...     11   17    10
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-17 11:00:00         4.916667  ...     11   17    11
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-17 12:00:00         4.916667  ...     11   17    12
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-17 13:00:00         4.916667  ...     11   17    13
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-17 14:00:00         4.916667  ...     11   17    14
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-17 15:00:00         4.916667  ...     11   17    15
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-17 16:00:00         4.916667  ...     11   17    16
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-17 17:00:00         4.916667  ...     11   17    17
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-17 18:00:00         4.916667  ...     11   17    18
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-17 19:00:00         4.916667  ...     11   17    19
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-17 20:00:00         4.916667  ...     11   17    20
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-17 21:00:00         4.916667  ...     11   17    21
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-17 22:00:00         4.916667  ...     11   17    22
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-17 23:00:00         4.916667  ...     11   17    23
#
# [1 rows x 10 columns]
#    site_id  timestamp  air_temperature  dew_temperature  ...  year  month  day  hour
# 0        5 2018-11-18         9.541667         8.291667  ...  2018     11   18     0
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-18 01:00:00         9.541667  ...     11   18     1
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-18 02:00:00         9.541667  ...     11   18     2
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-18 03:00:00         9.541667  ...     11   18     3
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-18 04:00:00         9.541667  ...     11   18     4
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-18 05:00:00         9.541667  ...     11   18     5
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-18 06:00:00         9.541667  ...     11   18     6
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-18 07:00:00         9.541667  ...     11   18     7
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-18 08:00:00         9.541667  ...     11   18     8
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-18 09:00:00         9.541667  ...     11   18     9
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-18 10:00:00         9.541667  ...     11   18    10
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-18 11:00:00         9.541667  ...     11   18    11
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-18 12:00:00         9.541667  ...     11   18    12
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-18 13:00:00         9.541667  ...     11   18    13
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-18 14:00:00         9.541667  ...     11   18    14
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-18 15:00:00         9.541667  ...     11   18    15
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-18 16:00:00         9.541667  ...     11   18    16
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        5 2018-11-18 17:00:00         9.541667  ...     11   18    17
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# ...
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-14 21:00:00           -4.875  ...     12   14    21
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-14 22:00:00           -4.875  ...     12   14    22
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-14 23:00:00           -4.875  ...     12   14    23
#
# [1 rows x 10 columns]
#    site_id  timestamp  air_temperature  dew_temperature  ...  year  month  day  hour
# 0       11 2017-12-15         1.183333        -0.279167  ...  2017     12   15     0
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-15 01:00:00         1.183333  ...     12   15     1
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-15 02:00:00         1.183333  ...     12   15     2
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-15 03:00:00         1.183333  ...     12   15     3
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-15 04:00:00         1.183333  ...     12   15     4
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-15 05:00:00         1.183333  ...     12   15     5
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-15 06:00:00         1.183333  ...     12   15     6
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-15 07:00:00         1.183333  ...     12   15     7
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-15 08:00:00         1.183333  ...     12   15     8
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-15 09:00:00         1.183333  ...     12   15     9
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-15 10:00:00         1.183333  ...     12   15    10
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-15 11:00:00         1.183333  ...     12   15    11
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-15 12:00:00         1.183333  ...     12   15    12
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-15 13:00:00         1.183333  ...     12   15    13
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-15 14:00:00         1.183333  ...     12   15    14
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-15 15:00:00         1.183333  ...     12   15    15
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-15 16:00:00         1.183333  ...     12   15    16
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-15 17:00:00         1.183333  ...     12   15    17
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-15 18:00:00         1.183333  ...     12   15    18
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-15 19:00:00         1.183333  ...     12   15    19
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-15 20:00:00         1.183333  ...     12   15    20
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-15 21:00:00         1.183333  ...     12   15    21
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-15 22:00:00         1.183333  ...     12   15    22
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-15 23:00:00         1.183333  ...     12   15    23
#
# [1 rows x 10 columns]
#    site_id  timestamp  air_temperature  dew_temperature  ...  year  month  day  hour
# 0       11 2017-12-16        -1.566667        -3.479167  ...  2017     12   16     0
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-16 01:00:00        -1.566667  ...     12   16     1
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-16 02:00:00        -1.566667  ...     12   16     2
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-16 03:00:00        -1.566667  ...     12   16     3
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-16 04:00:00        -1.566667  ...     12   16     4
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-16 05:00:00        -1.566667  ...     12   16     5
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-16 06:00:00        -1.566667  ...     12   16     6
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-16 07:00:00        -1.566667  ...     12   16     7
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-16 08:00:00        -1.566667  ...     12   16     8
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-16 09:00:00        -1.566667  ...     12   16     9
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-16 10:00:00        -1.566667  ...     12   16    10
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-16 11:00:00        -1.566667  ...     12   16    11
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-16 12:00:00        -1.566667  ...     12   16    12
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-16 13:00:00        -1.566667  ...     12   16    13
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-16 14:00:00        -1.566667  ...     12   16    14
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-16 15:00:00        -1.566667  ...     12   16    15
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-16 16:00:00        -1.566667  ...     12   16    16
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-16 17:00:00        -1.566667  ...     12   16    17
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-16 18:00:00        -1.566667  ...     12   16    18
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-16 19:00:00        -1.566667  ...     12   16    19
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-16 20:00:00        -1.566667  ...     12   16    20
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-16 21:00:00        -1.566667  ...     12   16    21
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-16 22:00:00        -1.566667  ...     12   16    22
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-16 23:00:00        -1.566667  ...     12   16    23
#
# [1 rows x 10 columns]
#    site_id  timestamp  air_temperature  dew_temperature  ...  year  month  day  hour
# 0       11 2017-12-17            -0.55        -2.791667  ...  2017     12   17     0
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-17 01:00:00            -0.55  ...     12   17     1
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-17 02:00:00            -0.55  ...     12   17     2
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-17 03:00:00            -0.55  ...     12   17     3
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-17 04:00:00            -0.55  ...     12   17     4
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-17 05:00:00            -0.55  ...     12   17     5
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-17 06:00:00            -0.55  ...     12   17     6
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-17 07:00:00            -0.55  ...     12   17     7
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-17 08:00:00            -0.55  ...     12   17     8
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-17 09:00:00            -0.55  ...     12   17     9
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-17 10:00:00            -0.55  ...     12   17    10
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-17 11:00:00            -0.55  ...     12   17    11
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-17 12:00:00            -0.55  ...     12   17    12
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-17 13:00:00            -0.55  ...     12   17    13
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-17 14:00:00            -0.55  ...     12   17    14
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-17 15:00:00            -0.55  ...     12   17    15
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-17 16:00:00            -0.55  ...     12   17    16
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-17 17:00:00            -0.55  ...     12   17    17
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-17 18:00:00            -0.55  ...     12   17    18
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-17 19:00:00            -0.55  ...     12   17    19
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-17 20:00:00            -0.55  ...     12   17    20
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-17 21:00:00            -0.55  ...     12   17    21
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-17 22:00:00            -0.55  ...     12   17    22
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-17 23:00:00            -0.55  ...     12   17    23
#
# [1 rows x 10 columns]
#    site_id  timestamp  air_temperature  dew_temperature  ...  year  month  day  hour
# 0       11 2017-12-18        -7.653846       -12.807692  ...  2017     12   18     0
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-18 01:00:00        -7.653846  ...     12   18     1
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-18 02:00:00        -7.653846  ...     12   18     2
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-18 03:00:00        -7.653846  ...     12   18     3
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-18 04:00:00        -7.653846  ...     12   18     4
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-18 05:00:00        -7.653846  ...     12   18     5
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-18 06:00:00        -7.653846  ...     12   18     6
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-18 07:00:00        -7.653846  ...     12   18     7
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-18 08:00:00        -7.653846  ...     12   18     8
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-18 09:00:00        -7.653846  ...     12   18     9
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-18 10:00:00        -7.653846  ...     12   18    10
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-18 11:00:00        -7.653846  ...     12   18    11
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-18 12:00:00        -7.653846  ...     12   18    12
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-18 13:00:00        -7.653846  ...     12   18    13
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-18 14:00:00        -7.653846  ...     12   18    14
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-18 15:00:00        -7.653846  ...     12   18    15
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-18 16:00:00        -7.653846  ...     12   18    16
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-18 17:00:00        -7.653846  ...     12   18    17
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-18 18:00:00        -7.653846  ...     12   18    18
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-18 19:00:00        -7.653846  ...     12   18    19
#
# [1 rows x 10 columns]
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0       11 2017-12-18 20:00:00        -7.653846  ...     12   18    20
#
# [1 rows x 10 columns]

# %%
appended_weather.drop_duplicates(subset=None, keep='first', inplace=True)

# %%
appended_weather = appended_weather.sort_values(by=['site_id', 'timestamp'])

# %%
print(appended_weather.shape[0]-final_weather.shape[0])
print(count)
print(new_count)
print(count+new_count)
# Out:
# 2041
# 2244
# 2017
# 4261

# %%
len(third_null_weather_times)
# Out:
# 2017

# %% [markdown]
# Merge again with filled in weather timestamps

# %%
new_merged_data = building_meter_data.merge(appended_weather, how = 'left', on=['timestamp', 'site_id'])
new_merged_data.loc[new_merged_data.air_temperature.isnull(), ].shape
# Out:
# (19197, 17)

# %%
final_null_weather_times = new_merged_data.loc[new_merged_data.air_temperature.isnull(), ['timestamp', 'site_id']]
final_null_weather_times.drop_duplicates(subset=None, keep='first', inplace=True)

# %%
final_null_weather_times
# Out:
#                    timestamp  site_id
# 41499327 2018-07-08 16:00:00        1
# 41499390 2018-07-08 17:00:00        1
# 41499957 2018-09-15 18:00:00        1
# 41500083 2018-09-15 20:00:00        1
# 41500272 2018-09-16 00:00:00        1
# ...                      ...      ...
# 41693434 2017-12-07 20:00:00       11
# 41693840 2017-12-09 01:00:00       11
# 41693938 2017-12-09 11:00:00       11
# 41694008 2017-12-10 14:00:00       11
# 41696794 2017-12-18 21:00:00       11
#
# [203 rows x 2 columns]

# %%
missing_months = [(time.site_id, time.timestamp.month, time.timestamp.hour)for index, time in final_null_weather_times.iterrows()]

# %%
set(missing_months)
# Out:
# {(1, 7, 16),
#  (1, 7, 17),
#  (1, 9, 0),
#  (1, 9, 4),
#  (1, 9, 8),
#  (1, 9, 15),
#  (1, 9, 16),
#  (1, 9, 18),
#  (1, 9, 20),
#  (1, 9, 23),
#  (1, 11, 18),
#  (1, 11, 20),
#  (5, 4, 12),
#  (5, 4, 18),
#  (5, 7, 16),
#  (5, 7, 17),
#  (5, 8, 2),
#  (5, 8, 3),
#  (5, 9, 1),
#  (5, 9, 4),
#  (5, 9, 6),
#  (5, 9, 8),
#  (5, 9, 9),
#  (5, 9, 18),
#  (5, 9, 20),
#  (5, 9, 23),
#  (5, 11, 18),
#  (5, 11, 20),
#  (6, 11, 21),
#  (6, 11, 22),
#  (7, 1, 3),
#  (7, 1, 5),
#  (7, 1, 7),
#  (7, 1, 11),
#  (7, 1, 13),
#  (7, 2, 11),
#  (7, 2, 16),
#  (7, 2, 17),
#  (7, 3, 13),
#  (7, 3, 23),
#  (7, 4, 11),
#  (7, 4, 12),
#  (7, 4, 14),
#  (7, 4, 16),
#  (7, 4, 17),
#  (7, 4, 19),
#  (7, 6, 0),
#  (7, 6, 4),
#  (7, 6, 6),
#  (7, 6, 11),
#  (7, 7, 9),
#  (7, 7, 23),
#  (7, 8, 3),
#  (7, 8, 9),
#  (7, 8, 11),
#  (7, 8, 14),
#  (7, 8, 23),
#  (7, 9, 4),
#  (7, 9, 8),
#  (7, 9, 9),
#  (7, 9, 11),
#  (7, 9, 16),
#  (7, 9, 17),
#  (7, 9, 22),
#  (7, 9, 23),
#  (7, 10, 2),
#  (7, 10, 4),
#  (7, 10, 16),
#  (7, 10, 18),
#  (7, 11, 10),
#  (7, 11, 13),
#  (7, 11, 18),
#  (7, 11, 20),
#  (7, 12, 1),
#  (7, 12, 11),
#  (7, 12, 14),
#  (7, 12, 20),
#  (7, 12, 21),
#  (9, 8, 7),
#  (9, 8, 13),
#  (9, 12, 0),
#  (9, 12, 11),
#  (10, 8, 9),
#  (10, 8, 12),
#  (10, 9, 4),
#  (10, 9, 7),
#  (11, 1, 3),
#  (11, 1, 5),
#  (11, 1, 7),
#  (11, 1, 11),
#  (11, 1, 13),
#  (11, 2, 11),
#  (11, 2, 16),
#  (11, 2, 17),
#  (11, 3, 13),
#  (11, 3, 23),
#  (11, 4, 11),
#  (11, 4, 12),
#  (11, 4, 14),
#  (11, 4, 16),
#  (11, 4, 17),
#  (11, 4, 19),
#  (11, 6, 0),
#  (11, 6, 4),
#  (11, 6, 6),
#  (11, 6, 11),
#  (11, 7, 9),
#  (11, 7, 23),
#  (11, 8, 3),
#  (11, 8, 9),
#  (11, 8, 11),
#  (11, 8, 14),
#  (11, 8, 23),
#  (11, 9, 4),
#  (11, 9, 8),
#  (11, 9, 9),
#  (11, 9, 11),
#  (11, 9, 16),
#  (11, 9, 17),
#  (11, 9, 22),
#  (11, 9, 23),
#  (11, 10, 2),
#  (11, 10, 4),
#  (11, 10, 16),
#  (11, 10, 18),
#  (11, 11, 10),
#  (11, 11, 13),
#  (11, 11, 18),
#  (11, 11, 20),
#  (11, 12, 1),
#  (11, 12, 11),
#  (11, 12, 14),
#  (11, 12, 20),
#  (11, 12, 21),
#  (12, 7, 16),
#  (12, 7, 17),
#  (12, 9, 1),
#  (12, 9, 4),
#  (12, 9, 7),
#  (12, 9, 16),
#  (12, 9, 20),
#  (12, 9, 23),
#  (12, 10, 18),
#  (12, 10, 20),
#  (12, 11, 18),
#  (12, 11, 20),
#  (15, 2, 5),
#  (15, 2, 8),
#  (15, 4, 4),
#  (15, 5, 4),
#  (15, 5, 9),
#  (15, 6, 4),
#  (15, 6, 5),
#  (15, 6, 7),
#  (15, 6, 8),
#  (15, 6, 9),
#  (15, 9, 4),
#  (15, 9, 7),
#  (15, 11, 5),
#  (15, 11, 8),
#  (15, 11, 9),
#  (15, 12, 5),
#  (15, 12, 8),
#  (15, 12, 9)}

# %%
last_shot = appended_weather.copy()

# %%
third_null_weather_times = []
new_count = 0
count = 0
for index, timeset in final_null_weather_times.iterrows():
  time_val = timeset.timestamp
  site = timeset.site_id
  prev_hour = appended_weather.loc[(appended_weather.timestamp == (final_null_weather_times.loc[index, 'timestamp'] - np.timedelta64(1, 'h'))) & (appended_weather.site_id ==site) ,] if time_val.hour != 0 else float('NaN')
  next_hour = appended_weather.loc[(appended_weather.timestamp == (final_null_weather_times.loc[index, 'timestamp'] + np.timedelta64(1, 'h'))) & (appended_weather.site_id ==site) ,] if time_val.hour != 11 else float('NaN')
  if not isinstance(prev_hour, float):  
    prev_hour = float('NaN') if prev_hour.empty else prev_hour
  if not isinstance(next_hour, float):
    next_hour = float('NaN') if next_hour.empty else next_hour
  if isinstance(prev_hour, float): # no prev row
    if isinstance(next_hour, float):
      # print(index, "NO SURROUNDING TIME STAMP")
      # take the average of mnth and day for that site
      site_data = appended_weather.loc[(appended_weather.site_id == site) & (appended_weather.month == time_val.month) & (appended_weather.day == time_val.day),]
      new_count+= 1
      count+= 1
      final_null_weather_times.append([time_val, site])
      test_means = np.mean(site_data.loc[:,['air_temperature', 'dew_temperature', 'wind_direction', 'wind_speed']]).values
      new_row_array = [site, time_val]
      for value in test_means:
        new_row_array.append(value)
      new_row_array.append(time_val.year)
      new_row_array.append(time_val.month)
      new_row_array.append(time_val.day)
      new_row_array.append(time_val.hour)
      new_row = pd.DataFrame([new_row_array], columns=last_shot.columns)
      print(new_row)
    else:
      new_row = next_hour
     # print(index, "prev_only")
      new_row.iloc[0].timestamp = time_val
      new_row.iloc[0].month = time_val.month
      new_row.iloc[0].day = time_val.day
      new_row.iloc[0].hour = time_val.hour
      count+= 1
     # print(new_row, " prev_only")
  elif isinstance(next_hour, float): # prev row, no future row
    new_row = prev_hour
   # print(index, "future only")
    new_row.iloc[0].timestamp = time_val
    new_row.iloc[0].month = time_val.month
    new_row.iloc[0].day = time_val.day
    new_row.iloc[0].hour = time_val.hour
    count+= 1
  #  print(new_row, " future_only")
  else: # average both rows
    # join two rows
  #  print(index, "both")
    both_rows = prev_hour.append(next_hour)
    test_means = np.mean(both_rows.loc[:,['air_temperature', 'dew_temperature', 'wind_direction', 'wind_speed']]).values
    new_row_array = [site, time_val]
    for value in test_means:
      new_row_array.append(value)
    new_row_array.append(time_val.year)
    new_row_array.append(time_val.month)
    new_row_array.append(time_val.day)
    new_row_array.append(time_val.hour)
    new_row = pd.DataFrame([new_row_array], columns=last_shot.columns)
   # print(new_row, " both") 
    count+= 1
  last_shot = last_shot.append(new_row)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
last_shot.drop_duplicates(subset=None, keep='first', inplace=True)

# %%
last_shot = last_shot.sort_values(by=['site_id', 'timestamp'])

# %%
print(last_shot.shape[0]-appended_weather.shape[0])
print(count)
print(new_count)
print(count+new_count)
# Out:
# 164
# 203
# 0
# 203

# %%
len(third_null_weather_times)
# Out:
# 0

# %% [markdown]
# FINAL MERGE ATTEMPT

# %%
final_merge = building_meter_data.merge(manually_adjusted, how = 'left', on=['timestamp', 'site_id'])

# %%
final_merge.head()

# %% [markdown]
# Manually filled in remaining missing timestamps (holidays like Thanksgiving and MLK day where several sites were missing the same timestamp across the board, but these values were lost and did not make a huge impact as var as the density levels of the final merged dataset: .95 --> .99)

# %%
for site in manually_adjusted.site_id.unique():
  site_data = manually_adjusted.loc[manually_adjusted.site_id == site]
  print(site_data.shape)
# Out:
# (8784, 10)
# (8784, 10)
# (8784, 10)
# (8784, 10)
# (8784, 10)
# (8784, 10)
# (8784, 10)
# (8784, 10)
# (8784, 10)
# (8784, 10)
# (8784, 10)
# (8784, 10)
# (8784, 10)
# (8784, 10)
# (8784, 10)
# (8780, 10)

# %%
site_0 = last_shot.loc[last_shot.site_id == 15,]

# %%
for month in site_0.month.unique():
  print(site_0.loc[site_0.month == month,].shape[0])
# Out:
# 744
# 696
# 740
# 720
# 744
# 718
# 744
# 742
# 720
# 744
# 720
# 744

# %%
count = 1
for day in site_0.loc[site_0.month == 2,].day.unique():
  day_data = site_0.loc[(site_0.month == 2) & (site_0.day == day),]
  print(count, day_data.shape)
  count+=1
# Out:
# 1 (24, 10)
# 2 (24, 10)
# 3 (24, 10)
# 4 (24, 10)
# 5 (24, 10)
# 6 (24, 10)
# 7 (24, 10)
# 8 (24, 10)
# 9 (24, 10)
# 10 (24, 10)
# 11 (24, 10)
# 12 (24, 10)
# 13 (24, 10)
# 14 (24, 10)
# 15 (22, 10)
# 16 (24, 10)
# 17 (24, 10)
# 18 (24, 10)
# 19 (24, 10)
# 20 (24, 10)
# 21 (24, 10)
# 22 (24, 10)
# 23 (24, 10)
# 24 (24, 10)
# 25 (24, 10)
# 26 (24, 10)
# 27 (24, 10)
# 28 (24, 10)
# 29 (24, 10)

# %%
site_0.loc[(site_0.month == 2) & (site_0.day == 15),]
# Out:
#       site_id           timestamp  air_temperature  ...  month  day  hour
# 9864        1 2016-02-15 00:00:00             1.70  ...      2   15     0
# 9865        1 2016-02-15 01:00:00             1.10  ...      2   15     1
# 9866        1 2016-02-15 02:00:00             0.80  ...      2   15     2
# 9867        1 2016-02-15 03:00:00             0.50  ...      2   15     3
# 9868        1 2016-02-15 04:00:00             0.60  ...      2   15     4
# 9869        1 2016-02-15 05:00:00             0.20  ...      2   15     5
# 9870        1 2016-02-15 06:00:00             0.50  ...      2   15     6
# 9871        1 2016-02-15 07:00:00             0.90  ...      2   15     7
# 9872        1 2016-02-15 08:00:00             2.00  ...      2   15     8
# 9873        1 2016-02-15 09:00:00             2.60  ...      2   15     9
# 9874        1 2016-02-15 10:00:00             3.70  ...      2   15    10
# 9875        1 2016-02-15 11:00:00             5.00  ...      2   15    11
# 9876        1 2016-02-15 12:00:00             5.10  ...      2   15    12
# 9877        1 2016-02-15 13:00:00             6.00  ...      2   15    13
# 9877        1 2016-02-15 14:00:00             6.00  ...      2   15    14
# 9878        1 2016-02-15 17:00:00             4.80  ...      2   15    17
# 9878        1 2016-02-15 18:00:00             4.80  ...      2   15    18
# 9879        1 2016-02-15 19:00:00             3.80  ...      2   15    19
# 0           1 2016-02-15 20:00:00             3.55  ...      2   15    20
# 9880        1 2016-02-15 21:00:00             3.30  ...      2   15    21
# 9881        1 2016-02-15 22:00:00             2.70  ...      2   15    22
# 9882        1 2016-02-15 23:00:00             1.90  ...      2   15    23
#
# [22 rows x 10 columns]

# %%
manually_adjusted = last_shot.copy()

# %%
seven_done = manually_adjusted.copy()

# %%
manually_add = last_shot.loc[(last_shot.site_id == 1) & (last_shot.month == 2) & ((last_shot.day == 15))& ((last_shot.hour == 14) | (last_shot.hour == 17)),]

# %%
manually_add
# Out:
#       site_id           timestamp  air_temperature  ...  month  day  hour
# 9877        1 2016-02-15 14:00:00              6.0  ...      2   15    14
# 9878        1 2016-02-15 17:00:00              4.8  ...      2   15    17
#
# [2 rows x 10 columns]

# %%
time_val = pd.Timestamp(2016, 2, 15, 16)

# %%
test_means = np.mean(manually_add.loc[:,['air_temperature', 'dew_temperature', 'wind_direction', 'wind_speed']]).values
new_row_array = [1, time_val]
for value in test_means:
  new_row_array.append(value)
new_row_array.append(time_val.year)
new_row_array.append(time_val.month)
new_row_array.append(time_val.day)
new_row_array.append(time_val.hour)
new_row = pd.DataFrame([new_row_array], columns=last_shot.columns)

# %%
new_row
# Out:
#    site_id           timestamp  air_temperature  ...  month  day  hour
# 0        1 2016-02-15 16:00:00              5.4  ...      2   15    16
#
# [1 rows x 10 columns]

# %%
manually_adjusted = manually_adjusted.append(new_row)

# %%
manually_adjusted.tail(25)
# Out:
#         site_id           timestamp  air_temperature  ...  month  day  hour
# 139771       15 2016-12-31 22:00:00             2.20  ...     12   31    22
# 139772       15 2016-12-31 23:00:00             1.70  ...     12   31    23
# 0            15 2016-06-28 15:00:00            24.20  ...      6   28    15
# 0            15 2016-06-28 16:00:00            24.20  ...      6   28    16
# 0            15 2016-08-18 22:00:00            24.10  ...      8   18    22
# 0            15 2016-08-18 23:00:00            24.10  ...      8   18    23
# 0            12 2016-02-18 17:00:00             4.60  ...      2   18    17
# 0            12 2016-02-18 18:00:00             4.60  ...      2   18    18
# 0            12 2016-11-23 00:00:00             0.95  ...     11   23     0
# 0            11 2016-01-06 11:00:00           -11.00  ...      1    6    11
# 0            11 2016-02-15 14:00:00           -19.35  ...      2   15    14
# 0            11 2016-02-15 15:00:00           -19.35  ...      2   15    15
# 0            11 2016-02-18 16:00:00           -13.30  ...      2   18    16
# 0            11 2016-11-23 00:00:00            -1.30  ...     11   23     0
# 0             7 2016-11-23 00:00:00            -1.30  ...     11   23     0
# 0             5 2016-11-23 00:00:00             6.00  ...     11   23     0
# 0             1 2016-11-23 00:00:00             6.25  ...     11   23     0
# 0            11 2016-02-18 17:00:00           -13.30  ...      2   18    17
# 0             7 2016-01-06 11:00:00           -11.00  ...      1    6    11
# 0             7 2016-02-15 14:00:00           -19.35  ...      2   15    14
# 0             7 2016-02-15 15:00:00           -19.35  ...      2   15    15
# 0             7 2016-02-18 16:00:00           -13.30  ...      2   18    16
# 0             7 2016-02-18 17:00:00           -13.30  ...      2   18    17
# 0             1 2016-02-15 15:00:00             5.40  ...      2   15    15
# 0             1 2016-02-15 16:00:00             5.40  ...      2   15    16
#
# [25 rows x 10 columns]

# %%
manually_adjusted.iloc[-6]
# Out:
# site_id                             12
# timestamp          2016-11-23 00:00:00
# air_temperature                   0.95
# dew_temperature                   -0.3
# wind_direction                     310
# wind_speed                         4.5
# year                              2016
# month                               11
# day                                 23
# hour                                 0
# Name: 0, dtype: object

# %%
last_shot.to_csv(p('updated_weather_test.csv'))
